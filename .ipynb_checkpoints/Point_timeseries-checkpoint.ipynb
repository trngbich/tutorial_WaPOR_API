# %% [markdown]
# # Step 1: Query load

# %%
point= [37.95883206252312, 7.89534] #latlon

query_pixeltimeseries={
  "type": "PixelTimeSeries",
  "params": {
    "cube": {
      "code": "L1_AETI_M",
      "workspaceCode": "WAPOR_2",
      "language": "en"
    },
    "dimensions": [
      {
        "code": "MONTH",
        "range": "[2009-01-01,2012-01-01)"
      }
    ],
    "measures": [
      "WATER_MM"
    ],
    "point": {
      "crs": "EPSG:4326", #latlon projection              
      "x":point[0],
        "y":point[1]
    }
  }
}

query_pixeltimeseries
# Out:
# {'type': 'PixelTimeSeries',
#  'params': {'cube': {'code': 'L1_AETI_M',
#    'workspaceCode': 'WAPOR_2',
#    'language': 'en'},
#   'dimensions': [{'code': 'MONTH', 'range': '[2009-01-01,2012-01-01)'}],
#   'measures': ['WATER_MM'],
#   'point': {'crs': 'EPSG:4326', 'x': 37.95883206252312, 'y': 7.89534}}}

# %% [markdown]
# # Step 2: Send query request

# %%
import requests
path_query=r'https://io.apps.fao.org/gismgr/api/v1/query/'

resp_query=requests.post(path_query,json=query_pixeltimeseries)
resp=resp_query.json()
resp
# Out:
# {'requestId': 'c47624ac-96ec-4bf3-afad-aca9e310c672',
#  'timestamp': 1569315268974,
#  'runtime': 6316,
#  'status': 200,
#  'message': 'OK',
#  'response': {'header': ['month', 'value'],
#   'items': [['2009-01-31', 78.0],
#    ['2009-02-28', 93.0],
#    ['2009-03-31', 93.5],
#    ['2009-04-30', 107.0],
#    ['2009-05-31', 124.10000000000001],
#    ['2009-06-30', 108.0],
#    ['2009-07-31', 82.7],
#    ['2009-08-31', 81.7],
#    ['2009-09-30', 90.0],
#    ['2009-10-31', 105.10000000000001],
#    ['2009-11-30', 116.0],
#    ['2009-12-31', 77.0],
#    ['2010-01-31', 119.5],
#    ['2010-02-28', 92.2],
#    ['2010-03-31', 122.7],
#    ['2010-04-30', 118.0],
#    ['2010-05-31', 93.10000000000001],
#    ['2010-06-30', 79.0],
#    ['2010-07-31', 54.7],
#    ['2010-08-31', 58.800000000000004],
#    ['2010-09-30', 80.0],
#    ['2010-10-31', 106.30000000000001],
#    ['2010-11-30', 79.0],
#    ['2010-12-31', 85.60000000000001],
#    ['2011-01-31', 96.7],
#    ['2011-02-28', 96.60000000000001],
#    ['2011-03-31', 103.30000000000001],
#    ['2011-04-30', 113.0],
#    ['2011-05-31', 107.60000000000001],
#    ['2011-06-30', 70.0],
#    ['2011-07-31', 70.2],
#    ['2011-08-31', 69.2],
#    ['2011-09-30', 90.0],
#    ['2011-10-31', 131.3],
#    ['2011-11-30', 94.0],
#    ['2011-12-31', 93.9]],
#   'stats': {'count': 36,
#    'min': 54.7,
#    'max': 131.3,
#    'range': 76.60000000000001,
#    'sum': 3380.7999999999997,
#    'mean': 93.9111111111111,
#    'std': 18.435936792908063}}}

# %% [markdown]
# # Step 3: Get request results

# %%
import pandas as pd
results=resp['response']
df=pd.DataFrame(results['items'],columns=results['header'])
df
# Out:
#          month  value
# 0   2009-01-31   78.0
# 1   2009-02-28   93.0
# 2   2009-03-31   93.5
# 3   2009-04-30  107.0
# 4   2009-05-31  124.1
# 5   2009-06-30  108.0
# 6   2009-07-31   82.7
# 7   2009-08-31   81.7
# 8   2009-09-30   90.0
# 9   2009-10-31  105.1
# 10  2009-11-30  116.0
# 11  2009-12-31   77.0
# 12  2010-01-31  119.5
# 13  2010-02-28   92.2
# 14  2010-03-31  122.7
# 15  2010-04-30  118.0
# 16  2010-05-31   93.1
# 17  2010-06-30   79.0
# 18  2010-07-31   54.7
# 19  2010-08-31   58.8
# 20  2010-09-30   80.0
# 21  2010-10-31  106.3
# 22  2010-11-30   79.0
# 23  2010-12-31   85.6
# 24  2011-01-31   96.7
# 25  2011-02-28   96.6
# 26  2011-03-31  103.3
# 27  2011-04-30  113.0
# 28  2011-05-31  107.6
# 29  2011-06-30   70.0
# 30  2011-07-31   70.2
# 31  2011-08-31   69.2
# 32  2011-09-30   90.0
# 33  2011-10-31  131.3
# 34  2011-11-30   94.0
# 35  2011-12-31   93.9

# %%
from matplotlib import pyplot as plt
plt.plot(df['value'])
plt.show()
