# %% [markdown]
# # Step 1: Read APIToken
#
# Get your APItoken from https://wapor.apps.fao.org/profile

# %%
import requests
import pandas as pd

path_query=r'https://io.apps.fao.org/gismgr/api/v1/query/'
path_sign_in=r'https://io.apps.fao.org/gismgr/api/v1/iam/sign-in/'

APIToken=input('Your API token: ')

# %% [markdown]
# # Step 2: Get Authorization AccessToken
#
# Using the input API token to get AccessToken for authorization

# %%
resp_signin=requests.post(path_sign_in,headers={'X-GISMGR-API-KEY':APIToken})
resp_signin = resp_signin.json()
AccessToken=resp_signin['response']['accessToken']

AccessToken
# Out:
# 'eyJhbGciOiJSUzI1NiIsImtpZCI6ImM4NDI1Zjk0YmVlMWU0N2YxNGQ3OWZhYmQ4MTIyNTRiMWJmOTE4YzAiLCJ0eXAiOiJKV1QifQ.....eZ_IqKGQqR4crvEhpEB2qyMvYhofLUQH23dTqnxQMxYBXDPpckaXx8gDO3iVSSMa-KVBuWxE-xhtfuBoAhKIFlwCzV5u2b7rHeErdROp5d7g2j_uDLyuEDMk-dmq5ZYM9sYsfD174z22CA_U_nXYv5eirakSS_FqclGO6-KsIJKKr6xm2xeRORm6Oia3rHwkwMxmxsXAT9fxf00xIUzPvGPTRHKpOg1HGDOxLib_dNdkEAvtlch0RLwWUYH2IKMVbyY-B5i7jyyOmmn4wtjwWWk8uxkrTiD7lwmRBZxQ7QaIgeQCsgG9nzqWo83_Wbep76FsBJ3JoECYAbeed8caqQ'

# %% [markdown]
# # Step 3: Define Polygon shape

# %% [markdown]
# ## Method 1: Define area by coordinate extent

# %%
coordinates=[
[39.2257,8.509], #x(lon),y(lat)
[39.1771,8.4634],
[39.2007,8.3805],
[39.227,8.3225],
[39.3296,8.3321],
[39.3339,8.4744],
]
projection="epsg:4326" #latlon projection

# %%
shape= {
  "type": "Polygon",
  "properties": {
  "name": projection 
          },
  "coordinates": [
   coordinates
  ]
}

# %% [markdown]
# ## Method 2: Define area by shapefile

# %%
import ogr
shp_fh=r"D:\FAO\Training\ETH_1907\ForUSB\Exercise\Awash\Awash_shapefile\Awash_shapefile.shp"

shpfile=ogr.Open(shp_fh)
layer=shpfile.GetLayer()
epsg_code=layer.GetSpatialRef().GetAuthorityCode(None)
shape=layer.GetFeature(0).ExportToJson(as_object=True)['geometry']
shape["properties"]={"name": "EPSG:{0}".format(epsg_code)}#latlon projection

# %%
shape

# %% [markdown]
# # Step 4: Post Query Load
#
# For more examples of areatimeseries query load
# visit https://io.apps.fao.org/gismgr/api/v1/swagger-ui/examples/AreaStatsTimeSeries.txt

# %%
query_areatimeseries={
  "type": "AreaStatsTimeSeries",
  "params": {
    "cube": {
      "code": "L1_PCP_E",
      "workspaceCode": "WAPOR_2",
      "language": "en"
    },
    "dimensions": [
      {
        "code": "DAY",
        "range": "[2009-01-01,2019-01-01)"
      }
    ],
    "measures": [
      "WATER_MM"
    ],
    "shape": shape
  }
}

# %% [markdown]
# Post the QueryPayload with AccessToken in Header. In responses, get an url to query job.

# %%
resp_query=requests.post(path_query,headers={'Authorization':'Bearer {0}'.format(AccessToken)},
                                          json=query_areatimeseries)
resp_query = resp_query.json()
job_url=resp_query['response']['links'][0]['href']

job_url
# Out:
# 'https://io.apps.fao.org/gismgr/api/v1/catalog/workspaces/WAPOR_2/jobs/e99a9ca0-a7e3-4ab9-b6a9-0cfd79b9c9ac'

# %% [markdown]
# # Step 4: Get Job Results.
#
# It will take some time for the job to be finished. When the job is finished, its status will be changed from 'RUNNING' to 'COMPLETED' or 'COMPLETED WITH ERRORS'. If it is COMPLETED, the area time series results can be achieved from Response 'output'.

# %%
i=0
print('RUNNING',end=" ")
while i==0:        
    resp = requests.get(job_url)
    resp=resp.json()
    
    if resp['response']['status']=='RUNNING':
        print('.',end =" ")
    if resp['response']['status']=='COMPLETED':
        results=resp['response']['output']
        df=pd.DataFrame(results['items'],columns=results['header'])
        i=1
    if resp['response']['status']=='COMPLETED WITH ERRORS':
        print(resp['response']['log'])
        i=1       
df
# Out:
# RUNNING . . . . . . . . . . .
#              day        avg  min   max  range
# 0     2009-01-01   0.000000  0.0   0.0    0.0
# 1     2009-01-02   0.000000  0.0   0.0    0.0
# 2     2009-01-03   0.000000  0.0   0.0    0.0
# 3     2009-01-04   0.000000  0.0   0.0    0.0
# 4     2009-01-05   0.000000  0.0   0.0    0.0
# 5     2009-01-06   0.000000  0.0   0.0    0.0
# 6     2009-01-07   0.000000  0.0   0.0    0.0
# 7     2009-01-08   0.000000  0.0   0.0    0.0
# 8     2009-01-09   0.000000  0.0   0.0    0.0
# 9     2009-01-10   0.000000  0.0   0.0    0.0
# 10    2009-01-11   0.000000  0.0   0.0    0.0
# 11    2009-01-12   0.000000  0.0   0.0    0.0
# 12    2009-01-13   0.000000  0.0   0.0    0.0
# 13    2009-01-14   0.000000  0.0   0.0    0.0
# 14    2009-01-15   0.000000  0.0   0.0    0.0
# 15    2009-01-16   0.000000  0.0   0.0    0.0
# 16    2009-01-17   0.000000  0.0   0.0    0.0
# 17    2009-01-18   0.000000  0.0   0.0    0.0
# 18    2009-01-19   0.000000  0.0   0.0    0.0
# 19    2009-01-20   0.000000  0.0   0.0    0.0
# 20    2009-01-21   0.000000  0.0   0.0    0.0
# 21    2009-01-22   0.000000  0.0   0.0    0.0
# 22    2009-01-23   2.033333  0.0   7.9    7.9
# 23    2009-01-24   7.344444  5.0  10.7    5.7
# 24    2009-01-25  11.444444  7.9  13.7    5.8
# 25    2009-01-26   0.000000  0.0   0.0    0.0
# 26    2009-01-27   0.000000  0.0   0.0    0.0
# 27    2009-01-28   0.000000  0.0   0.0    0.0
# 28    2009-01-29   0.000000  0.0   0.0    0.0
# 29    2009-01-30   0.000000  0.0   0.0    0.0
# ...          ...        ...  ...   ...    ...
# 3622  2018-12-02   0.000000  0.0   0.0    0.0
# 3623  2018-12-03   0.000000  0.0   0.0    0.0
# 3624  2018-12-04   0.000000  0.0   0.0    0.0
# 3625  2018-12-05   0.000000  0.0   0.0    0.0
# 3626  2018-12-06   0.000000  0.0   0.0    0.0
# 3627  2018-12-07   0.000000  0.0   0.0    0.0
# 3628  2018-12-08   0.000000  0.0   0.0    0.0
# 3629  2018-12-09   0.000000  0.0   0.0    0.0
# 3630  2018-12-10   0.000000  0.0   0.0    0.0
# 3631  2018-12-11   0.000000  0.0   0.0    0.0
# 3632  2018-12-12   0.000000  0.0   0.0    0.0
# 3633  2018-12-13   0.000000  0.0   0.0    0.0
# 3634  2018-12-14   0.000000  0.0   0.0    0.0
# 3635  2018-12-15   0.000000  0.0   0.0    0.0
# 3636  2018-12-16   0.000000  0.0   0.0    0.0
# 3637  2018-12-17   0.000000  0.0   0.0    0.0
# 3638  2018-12-18   0.000000  0.0   0.0    0.0
# 3639  2018-12-19   0.000000  0.0   0.0    0.0
# 3640  2018-12-20   0.000000  0.0   0.0    0.0
# 3641  2018-12-21   0.066667  0.0   0.1    0.1
# 3642  2018-12-22   0.000000  0.0   0.0    0.0
# 3643  2018-12-23   1.733333  1.5   1.9    0.4
# 3644  2018-12-24   0.000000  0.0   0.0    0.0
# 3645  2018-12-25   0.000000  0.0   0.0    0.0
# 3646  2018-12-26   0.000000  0.0   0.0    0.0
# 3647  2018-12-27   0.000000  0.0   0.0    0.0
# 3648  2018-12-28   0.000000  0.0   0.0    0.0
# 3649  2018-12-29   0.000000  0.0   0.0    0.0
# 3650  2018-12-30   0.000000  0.0   0.0    0.0
# 3651  2018-12-31   0.000000  0.0   0.0    0.0
#
# [3652 rows x 5 columns]

# %% [markdown]
# ## Save result as csv file

# %%
output_file=r'D:\Test\PCP_polygon.csv'
df.to_csv(output_file,sep=';',index=False)

# %% [markdown]
# ## Plot the results

# %%
from matplotlib import pyplot as plt
plt.plot(df['avg'])
plt.show()
